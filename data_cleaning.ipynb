# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
population_data_to_load = "raw_data/population.csv"
number_house_data_to_load = "raw_data/number_of_houses_census_incl_county.csv"
value_housing_data_to_load = "raw_data/single_family_housing_value_zillow.csv"

# Read population and housing Data File and store into Pandas DataFrames
population_data = pd.read_csv(population_data_to_load)
number_house_data = pd.read_csv(number_house_data_to_load, encoding="latin-1")
value_housing_data = pd.read_csv(value_housing_data_to_load)

# %%
# df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
population_data.head(20)
# Out:
#     SUMLEV REGION DIVISION  STATE                  NAME  CENSUS2010POP  \
# 0       10      0        0      0         United States      308745538
# 1       20      1        0      0      Northeast Region       55317240
# 2       20      2        0      0        Midwest Region       66927001
# 3       20      3        0      0          South Region      114555744
# 4       20      4        0      0           West Region       71945553
# 5       40      3        6      1               Alabama        4779736
# 6       40      4        9      2                Alaska         710231
# 7       40      4        8      4               Arizona        6392017
# 8       40      3        7      5              Arkansas        2915918
# 9       40      4        9      6            California       37253956
# 10      40      4        8      8              Colorado        5029196
# 11      40      1        1      9           Connecticut        3574097
# ...

# %%
population_data.drop(['SUMLEV', 'REGION', 'DIVISION', 'STATE'], axis=1, inplace=True)
population_data.head()
# Out:
#                NAME  CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 0     United States      308745538          308758105        309321666
# 1  Northeast Region       55317240           55318443         55380134
# 2    Midwest Region       66927001           66929725         66974416
# 3      South Region      114555744          114563030        114866680
# 4       West Region       71945553           71946907         72100436
#
#    POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0        311556874        313830990        315993715        318301008
# 1         55604223         55775216         55901806         56006011
# 2         67157800         67336743         67560379         67745167
# 3        116006522        117241208        118364400        119624037
# 4         72788329         73477823         74167130         74925793
#
#    POPESTIMATE2015  POPESTIMATE2016  ...  RDOMESTICMIG2019  RNETMIG2011  \
# ...

# %%
population_data.columns
# Out:
# Index(['NAME', 'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'POPESTIMATE2016',
#        ...
#        'RDOMESTICMIG2019', 'RNETMIG2011', 'RNETMIG2012', 'RNETMIG2013',
#        'RNETMIG2014', 'RNETMIG2015', 'RNETMIG2016', 'RNETMIG2017',
#        'RNETMIG2018', 'RNETMIG2019'],
#       dtype='object', length=147)

# %%
population_data.count()
# Out:
# NAME                 57
# CENSUS2010POP        57
# ESTIMATESBASE2010    57
# POPESTIMATE2010      57
# POPESTIMATE2011      57
#                      ..
# RNETMIG2015          57
# RNETMIG2016          57
# RNETMIG2017          57
# RNETMIG2018          57
# RNETMIG2019          57
# Length: 147, dtype: int64

# %%
no_null_population_data = population_data.dropna(how='any')

# %%
no_null_population_data.count()
# Out:
# NAME                 57
# CENSUS2010POP        57
# ESTIMATESBASE2010    57
# POPESTIMATE2010      57
# POPESTIMATE2011      57
#                      ..
# RNETMIG2015          57
# RNETMIG2016          57
# RNETMIG2017          57
# RNETMIG2018          57
# RNETMIG2019          57
# Length: 147, dtype: int64

# %%
no_null_population_data["NAME"].value_counts()
# Out:
# United States           1
# Mississippi             1
# Montana                 1
# Nebraska                1
# Nevada                  1
# New Hampshire           1
# New Jersey              1
# New Mexico              1
# New York                1
# North Carolina          1
# North Dakota            1
# Ohio                    1
# Oklahoma                1
# Oregon                  1
# Pennsylvania            1
# Rhode Island            1
# South Carolina          1
# South Dakota            1
# Tennessee               1
# Texas                   1
# Utah                    1
# Vermont                 1
# Virginia                1
# Washington              1
# West Virginia           1
# Wisconsin               1
# Wyoming                 1
# Missouri                1
# Minnesota               1
# Northeast Region        1
# Michigan                1
# Midwest Region          1
# South Region            1
# West Region             1
# Alabama                 1
# ...

# %%
# net migration per state
net_state_migration = population_data[["NAME", "NETMIG2010", "NETMIG2011", "NETMIG2012", 
                                   "NETMIG2013", "NETMIG2014", "NETMIG2015", 
                                  "NETMIG2016", "NETMIG2017","NETMIG2018",
                                   "NETMIG2019"]]
net_state_migration.head(20)
# Out:
#                     NAME  NETMIG2010  NETMIG2011  NETMIG2012  NETMIG2013  \
# 0          United States      174416      774165      838671      830168
# 1       Northeast Region       12225       49272       -2136      -26232
# 2         Midwest Region      -25953      -64647      -65495        -467
# 3           South Region      158731      592249      682303      623421
# 4            West Region       29413      197291      223999      233446
# 5                Alabama        2168        2772        5703        7343
# 6                 Alaska        1598         422        1029        -701
# 7                Arizona        5672       27551       44944       42047
# 8               Arkansas        3270        9658        2439         171
# 9             California        -721       47853       56502       62836
# 10              Colorado        8433       39632       38739       44424
# 11           Connecticut        2572         869       -1471       -6007
# ...

# %%
net_state_migration.drop([0, 1, 2, 3, 4, 56], inplace=True)
# Out:
# /var/folders/_3/fpx1kffx6n90zjt7rjys0h6r0000gn/T/ipykernel_32855/2555151445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   net_state_migration.drop([0, 1, 2, 3, 4, 56], inplace=True)

# %%
net_state_migration.reset_index(drop=True)
# Out:
#                     NAME  NETMIG2010  NETMIG2011  NETMIG2012  NETMIG2013  \
# 0                Alabama        2168        2772        5703        7343
# 1                 Alaska        1598         422        1029        -701
# 2                Arizona        5672       27551       44944       42047
# 3               Arkansas        3270        9658        2439         171
# 4             California        -721       47853       56502       62836
# 5               Colorado        8433       39632       38739       44424
# 6            Connecticut        2572         869       -1471       -6007
# 7               Delaware         638        4381        4414        5655
# 8   District of Columbia        2169        9951       10095       10788
# 9                Florida       32460      169141      202523      215179
# 10               Georgia        7100       28820       36489       16454
# 11                Hawaii        1627        6340        7055        4917
# ...

# %%
state_migrate = net_state_migration.rename(columns = { "NAME" : "State" })
state_migrate
# Out:
#                    State  NETMIG2010  NETMIG2011  NETMIG2012  NETMIG2013  \
# 5                Alabama        2168        2772        5703        7343
# 6                 Alaska        1598         422        1029        -701
# 7                Arizona        5672       27551       44944       42047
# 8               Arkansas        3270        9658        2439         171
# 9             California        -721       47853       56502       62836
# 10              Colorado        8433       39632       38739       44424
# 11           Connecticut        2572         869       -1471       -6007
# 12              Delaware         638        4381        4414        5655
# 13  District of Columbia        2169        9951       10095       10788
# 14               Florida       32460      169141      202523      215179
# 15               Georgia        7100       28820       36489       16454
# 16                Hawaii        1627        6340        7055        4917
# ...

# %%
#number of house units
number_house_data.head(20)
# Out:
#     SUMLEV  REGION  STATE  COUNTY           REGNAME            STNAME  \
# 0       10       0      0       0     United States     United States
# 1       20       1      0       0  Northeast Region  Northeast Region
# 2       20       2      0       0    Midwest Region    Midwest Region
# 3       20       3      0       0      South Region      South Region
# 4       20       4      0       0       West Region       West Region
# 5       40       3      1       0      South Region           Alabama
# 6       50       3      1       1      South Region           Alabama
# 7       50       3      1       3      South Region           Alabama
# 8       50       3      1       5      South Region           Alabama
# 9       50       3      1       7      South Region           Alabama
# 10      50       3      1       9      South Region           Alabama
# 11      50       3      1      11      South Region           Alabama
# ...

# %%
number_house_data.drop(['SUMLEV', 'REGION', 'STATE', 'COUNTY', 'REGNAME',
                        'CENSUS2010HU', 'HUESTIMATESBASE2010', 
                        'HUESTIMATE042020', 'HUESTIMATE2020'], axis=1, inplace=True)
number_house_data.head()
# Out:
#              STNAME           CTYNAME  HUESTIMATE2010  HUESTIMATE2011  \
# 0     United States     United States       131832419       132319862
# 1  Northeast Region  Northeast Region        23667000        23739310
# 2    Midwest Region    Midwest Region        29497739        29561143
# 3      South Region      South Region        50039849        50273556
# 4       West Region       West Region        28627831        28745853
#
#    HUESTIMATE2012  HUESTIMATE2013  HUESTIMATE2014  HUESTIMATE2015  \
# 0       132832760       133522850       134349725       135227835
# 1        23800462        23865713        23944075        24025563
# 2        29628171        29722946        29837708        29963139
# 3        50535471        50901464        51334194        51791146
# 4        28868656        29032727        29233748        29447987
#
#    HUESTIMATE2016  HUESTIMATE2017  HUESTIMATE2018  HUESTIMATE2019
# 0       136201325       137259144       138391688       139553076
# ...

# %%
number_house_data.drop([0, 1, 2, 3, 4], inplace=True)

# %%
number_house_data.reset_index(drop=True)
# Out:
#        STNAME            CTYNAME  HUESTIMATE2010  HUESTIMATE2011  \
# 0     Alabama            Alabama         2174759         2181024
# 1     Alabama     Autauga County           22163           22339
# 2     Alabama     Baldwin County          104287          104911
# 3     Alabama     Barbour County           11830           11843
# 4     Alabama        Bibb County            8988            8995
# ...       ...                ...             ...             ...
# 3189  Wyoming  Sweetwater County           18823           18974
# 3190  Wyoming       Teton County           12835           12943
# 3191  Wyoming       Uinta County            8729            8777
# 3192  Wyoming    Washakie County            3833            3834
# 3193  Wyoming      Weston County            3535            3541
#
#       HUESTIMATE2012  HUESTIMATE2013  HUESTIMATE2014  HUESTIMATE2015  \
# 0            2191745         2203507         2213610         2225603
# ...

# %%
number_house_state = number_house_data.groupby( "STNAME", as_index=False).sum()
number_house_state
# Out:
#                   STNAME  HUESTIMATE2010  HUESTIMATE2011  HUESTIMATE2012  \
# 0                Alabama         4349518         4362048         4383490
# 1                 Alaska          614358          616992          619998
# 2                Arizona         5698980         5720358         5745976
# 3               Arkansas         2636144         2649274         2661856
# 4             California        27383186        27463486        27544642
# 5               Colorado         4433962         4449974         4469502
# 6            Connecticut         2977300         2983618         2988484
# 7               Delaware          813008          817886          822396
# 8   District of Columbia          593378          592732          599644
# 9                Florida        17990252        18041738        18100040
# 10               Georgia         8183938         8206404         8231776
# 11                Hawaii         1040176         1046426         1051356
# ...

# %%
housing_state = number_house_state.rename(columns = { "STNAME" : "State" })
housing_state
# Out:
#                    State  HUESTIMATE2010  HUESTIMATE2011  HUESTIMATE2012  \
# 0                Alabama         4349518         4362048         4383490
# 1                 Alaska          614358          616992          619998
# 2                Arizona         5698980         5720358         5745976
# 3               Arkansas         2636144         2649274         2661856
# 4             California        27383186        27463486        27544642
# 5               Colorado         4433962         4449974         4469502
# 6            Connecticut         2977300         2983618         2988484
# 7               Delaware          813008          817886          822396
# 8   District of Columbia          593378          592732          599644
# 9                Florida        17990252        18041738        18100040
# 10               Georgia         8183938         8206404         8231776
# 11                Hawaii         1040176         1046426         1051356
# ...

# %%
# zillow value of housing 
value_housing_data.head(20)
# Out:
#     RegionID  SizeRank      RegionName RegionType StateName  2000-01-31  \
# 0          9         0      California      State        CA    204441.0
# 1         54         1           Texas      State        TX    115200.0
# 2         43         2        New York      State        NY    140342.0
# 3         14         3         Florida      State        FL    120367.0
# 4         21         4        Illinois      State        IL    148918.0
# 5         47         5    Pennsylvania      State        PA    107087.0
# 6         44         6            Ohio      State        OH    111717.0
# 7         30         7        Michigan      State        MI    120753.0
# 8         16         8         Georgia      State        GA    131990.0
# 9         36         9  North Carolina      State        NC    135413.0
# 10        40        10      New Jersey      State        NJ    191821.0
# 11        56        11        Virginia      State        VA    137934.0
# ...

# %%
# house value per state
house_value = value_housing_data[['RegionName', '2010-01-31', '2010-02-28', '2010-03-31',
                                  '2010-04-30', '2010-05-31', '2010-06-30', '2010-07-31',
                                  '2010-08-31', '2010-09-30', '2010-10-31', '2010-11-30',
                                  '2010-12-31', '2011-01-31', '2011-02-28', '2011-03-31',
                                  '2011-04-30', '2011-05-31', '2011-06-30', '2011-07-31',
                                  '2011-08-31', '2011-09-30', '2011-10-31', '2011-11-30',
                                  '2011-12-31', '2012-01-31', '2012-02-29', '2012-03-31',
                                  '2012-04-30', '2012-05-31', '2012-06-30', '2012-07-31',
                                  '2012-08-31', '2012-09-30', '2012-10-31', '2012-11-30',
                                  '2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31',
                                  '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31',
                                  '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30',
                                  '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31',
                                  '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31',
                                  '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30',
                                  '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31',
                                  '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31',
                                  '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', 
                                  '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31',
                                  '2016-04-30', '2016-06-30', '2016-07-31', '2016-08-31', 
                                  '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31',
                                  '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', 
                                  '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31',
                                  '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31',
                                  '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30',
                                  '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', 
                                  '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31',
                                  '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30',
                                  '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31',
                                  '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31']]
house_value.head(20)
# Out:
#         RegionName  2010-01-31  2010-02-28  2010-03-31  2010-04-30  \
# 0       California    333758.0    334192.0    335474.0    337042.0
# 1            Texas    142908.0    142888.0    142989.0    143305.0
# 2         New York    233597.0    233636.0    233756.0    234275.0
# 3          Florida    167427.0    166843.0    166509.0    166170.0
# 4         Illinois    190098.0    189711.0    188463.0    188922.0
# 5     Pennsylvania    172726.0    173116.0    173675.0    174153.0
# 6             Ohio    123665.0    123615.0    123554.0    123625.0
# 7         Michigan    104403.0    103827.0    103532.0    103458.0
# 8          Georgia    147217.0    146585.0    146114.0    145973.0
# 9   North Carolina    167613.0    167164.0    166856.0    166772.0
# 10      New Jersey    338074.0    338222.0    338088.0    337875.0
# 11        Virginia    245497.0    245868.0    246281.0    246752.0
# 12      Washington    267813.0    266585.0    265599.0    266034.0
# ...

# %%
house_value.count()
# Out:
# RegionName    51
# 2010-01-31    51
# 2010-02-28    51
# 2010-03-31    51
# 2010-04-30    51
#               ..
# 2019-08-31    51
# 2019-09-30    51
# 2019-10-31    51
# 2019-11-30    51
# 2019-12-31    51
# Length: 120, dtype: int64

# %%
clean_data_house_value = house_value.fillna({"2019-04-30": 0})
clean_data_house_value.head(50)
# Out:
#               RegionName  2010-01-31  2010-02-28  2010-03-31  2010-04-30  \
# 0             California    333758.0    334192.0    335474.0    337042.0
# 1                  Texas    142908.0    142888.0    142989.0    143305.0
# 2               New York    233597.0    233636.0    233756.0    234275.0
# 3                Florida    167427.0    166843.0    166509.0    166170.0
# 4               Illinois    190098.0    189711.0    188463.0    188922.0
# 5           Pennsylvania    172726.0    173116.0    173675.0    174153.0
# 6                   Ohio    123665.0    123615.0    123554.0    123625.0
# 7               Michigan    104403.0    103827.0    103532.0    103458.0
# 8                Georgia    147217.0    146585.0    146114.0    145973.0
# 9         North Carolina    167613.0    167164.0    166856.0    166772.0
# 10            New Jersey    338074.0    338222.0    338088.0    337875.0
# 11              Virginia    245497.0    245868.0    246281.0    246752.0
# ...

# %%
annual_average_house = clean_data_house_value['RegionName'].tolist()

# %%
annual_average_house_df = pd.DataFrame({ 'State': annual_average_house })

# %%
ys = 0
for year in range(10,19):
    annual_average_house_df[f'20{year} average'] = clean_data_house_value.iloc[:,[1 + ys,2 + ys,3 + ys,4 + ys,5 + ys,6 + ys,7 + ys,8 + ys,9 + ys,10 + ys,11 + ys,12 + ys]].mean(axis=1)
    ys +=12
annual_average_house_df[f'2019 average'] = clean_data_house_value.iloc[:,[1 + ys,2 + ys,3 + ys,4 + ys,5 + ys,6 + ys,7 + ys,8 + ys,9 + ys,10 + ys,11 + ys]].mean(axis=1)

# %%
annual_average_house_df
# Out:
#                    State   2010 average   2011 average   2012 average  \
# 0             California  333805.000000  316157.333333  314443.666667
# 1                  Texas  142377.500000  137878.833333  138578.083333
# 2               New York  233849.750000  227594.500000  223461.500000
# 3                Florida  163079.750000  148066.083333  147267.000000
# 4               Illinois  186097.916667  170316.416667  160085.750000
# 5           Pennsylvania  172815.750000  165531.166667  161889.250000
# 6                   Ohio  122736.333333  116762.083333  113748.000000
# 7               Michigan  102940.916667   96526.500000   97362.250000
# 8                Georgia  143633.916667  130070.083333  126139.833333
# 9         North Carolina  165590.666667  158006.583333  153880.416667
# 10            New Jersey  334301.166667  313069.000000  296516.416667
# 11              Virginia  244846.000000  236663.833333  235436.750000
# ...

# %%
net_state_migration
# Out:
#                     NAME  NETMIG2010  NETMIG2011  NETMIG2012  NETMIG2013  \
# 5                Alabama        2168        2772        5703        7343
# 6                 Alaska        1598         422        1029        -701
# 7                Arizona        5672       27551       44944       42047
# 8               Arkansas        3270        9658        2439         171
# 9             California        -721       47853       56502       62836
# 10              Colorado        8433       39632       38739       44424
# 11           Connecticut        2572         869       -1471       -6007
# 12              Delaware         638        4381        4414        5655
# 13  District of Columbia        2169        9951       10095       10788
# 14               Florida       32460      169141      202523      215179
# 15               Georgia        7100       28820       36489       16454
# 16                Hawaii        1627        6340        7055        4917
# ...

# %%
merged_data_frame = pd.merge(state_migrate, housing_state, how='left', on=['State','State'] )

# %%
merged_data_frame
# Out:
#                    State  NETMIG2010  NETMIG2011  NETMIG2012  NETMIG2013  \
# 0                Alabama        2168        2772        5703        7343
# 1                 Alaska        1598         422        1029        -701
# 2                Arizona        5672       27551       44944       42047
# 3               Arkansas        3270        9658        2439         171
# 4             California        -721       47853       56502       62836
# 5               Colorado        8433       39632       38739       44424
# 6            Connecticut        2572         869       -1471       -6007
# 7               Delaware         638        4381        4414        5655
# 8   District of Columbia        2169        9951       10095       10788
# 9                Florida       32460      169141      202523      215179
# 10               Georgia        7100       28820       36489       16454
# 11                Hawaii        1627        6340        7055        4917
# ...

# %%
merged_data = pd.merge(merged_data_frame, annual_average_house_df, how='left', on=['State','State'] ) 
merged_data
# Out:
#                    State  NETMIG2010  NETMIG2011  NETMIG2012  NETMIG2013  \
# 0                Alabama        2168        2772        5703        7343
# 1                 Alaska        1598         422        1029        -701
# 2                Arizona        5672       27551       44944       42047
# 3               Arkansas        3270        9658        2439         171
# 4             California        -721       47853       56502       62836
# 5               Colorado        8433       39632       38739       44424
# 6            Connecticut        2572         869       -1471       -6007
# 7               Delaware         638        4381        4414        5655
# 8   District of Columbia        2169        9951       10095       10788
# 9                Florida       32460      169141      202523      215179
# 10               Georgia        7100       28820       36489       16454
# 11                Hawaii        1627        6340        7055        4917
# ...

# %%
merged_data.to_csv("Resources/final_data.csv")
